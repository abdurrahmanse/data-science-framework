# %% [markdown]
# # Basics — NumPy
#
# This notebook contains basic NumPy concepts and examples.

# %%
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Hello, World!

# %%
print("Hello world")
# Out:
# Hello world
